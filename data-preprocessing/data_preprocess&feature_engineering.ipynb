# %% [markdown]
# ## Import standard packages and helpers

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install python_rdrsegmenter
# Out:
# Collecting python_rdrsegmenter
#   Downloading python_rdrsegmenter-0.1.1-py3-none-any.whl (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.6/259.6 kB 1.4 MB/s eta 0:00:00
# Collecting pyjnius (from python_rdrsegmenter)
#   Downloading pyjnius-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 2.8 MB/s eta 0:00:00
# Installing collected packages: pyjnius, python_rdrsegmenter
# Successfully installed pyjnius-1.6.1 python_rdrsegmenter-0.1.1

# %%
from python_rdrsegmenter import load_segmenter

# %%
#from google.colab import files
#files.upload()

# %%
df = pd.read_excel("all_data.xlsx")
df.head()
# Out:
#                       Seller         Customer          Product name  \
# 0  Sweet mint Official Store      hai_yen2208  Pink Coco Son kem lì
# 1  Sweet mint Official Store          k*****5  Pink Coco Son kem lì
# 2  Sweet mint Official Store          p*****7  Pink Coco Son kem lì
# 3  Sweet mint Official Store     kitanhnguyen  Pink Coco Son kem lì
# 4  Sweet mint Official Store  phuongthao.alin  Pink Coco Son kem lì
#
#                  Date  Rating  \
# 0 2023-04-09 17:06:07       5
# 1 2023-04-17 05:44:39       1
# 2 2023-04-20 09:32:24       5
# 3 2023-05-23 05:08:56       5
# 4 2023-05-23 11:08:28       5
#
#                                               Review Version Oversea Shopping  \
# 0  Sản phẩm okla nha mn, màu lên đúng hình trên ả...       5               no
# 1  Sản phẩm thì là vỏ ko\nKo có son bên trong\nKo...       4               no
# 2  Làm đẹp:môi\n\nGiá rẻ mà chất lượng màu cũng s...       4               no
# 3  Hiệu ứng làm đẹp:rất là đẹp 😍\nKinh nghiệm sử ...       4               no
# 4  Hiệu ứng làm đẹp:tốt\nKinh nghiệm sử dụng:ko c...       2               no
#
#   Picture included
# 0               no
# 1               no
# 2              yes
# 3               no
# 4               no

# %% [markdown]
# # Add features to text data

# %%
df_text = df[["Seller", "Review"]].copy()

# %%
df_text["Review"] = df_text["Review"].str.replace(":", ": ")

# %%
df_text["Review"] = df_text["Review"].str.replace("\n", " ")

# %%
df_text["Review"] = df_text["Review"].str.replace(":", ": ")

# %%
df_text["Review"] = df_text["Review"].str.replace(",", ", ")

# %%
segmenter = load_segmenter()

# %%
segmenter.tokenize("Son thì bị vỡ vỏ , có  vs giá này thì ok")
# Out:
# '_Son thì bị vỡ vỏ , có vs giá này thì ok'

# %%
df_text["Review_new"] = [segmenter.tokenize(str(sentence)) for sentence in df_text["Review"]]

# %%
df_text["Char"] = [len(str(sentence)) for sentence in df_text["Review"]]

# %% [markdown]
# #### Vietnamese segmented word count

# %%
df_text["Segm_count"] = [len(segmenter.tokenize(str(sentence)).split()) for sentence in df_text["Review"]]

# %% [markdown]
# #### Raw word count

# %%
df_text["Word_count"] = [len(str(sentence).split()) for sentence in df_text["Review"]]

# %% [markdown]
# # Spam Traits

# %%
# In Vietnamese, the character length of each syllable is at most 7 (and there is only 1 instance, which is "nghiêng")
# Logically, sentennces with Char/Wcount >= 7 or close to 7 are spam comments
df_text["Char/Wcount"] = round(df_text["Char"] / df_text["Word_count"], 2)

# %%
df_text.head()
# Out:
#                       Seller  \
# 0  Sweet mint Official Store
# 1  Sweet mint Official Store
# 2  Sweet mint Official Store
# 3  Sweet mint Official Store
# 4  Sweet mint Official Store
#
#                                               Review  \
# 0  Sản phẩm okla nha mn,  màu lên đúng hình trên ...
# 1  Sản phẩm thì là vỏ ko Ko có son bên trong Ko h...
# 2  Làm đẹp: môi  Giá rẻ mà chất lượng màu cũng si...
# 3  Hiệu ứng làm đẹp: rất là đẹp 😍 Kinh nghiệm sử ...
# 4  Hiệu ứng làm đẹp: tốt Kinh nghiệm sử dụng: ko ...
#
#                                           Review_new  Char  Segm_count  \
# 0  Sản_phẩm okla nha mn, màu lên đúng hình trên ả...    74          13
# 1  Sản_phẩm thì là vỏ ko Ko có_son bên trong Ko h...    53          11
# 2  Làm đẹp: môi Giá rẻ mà chất_lượng màu cũng siê...    74          15
# 3  Hiệu_ứng làm đẹp: rất là đẹp 😍 Kinh_nghiệm sử ...    66          13
# 4  Hiệu_ứng làm đẹp: tốt Kinh_nghiệm sử dụng: ko ...    68          14
#
#    Word_count  Char/Wcount
# 0          15         4.93
# 1          14         3.79
# 2          16         4.62
# 3          16         4.12
# 4          16         4.25

# %%
spam_lower = df_text.loc[df_text["Char/Wcount"] < 3.5].sort_values(by="Char/Wcount")
spam_upper = df_text.loc[(df_text["Char/Wcount"] > 5)].sort_values(by="Char/Wcount")

# %%
spam_mid = df_text.loc[(df_text["Char/Wcount"] > 3.5) & (df_text["Char/Wcount"] < 5) & (df_text["Word_count"] < 4)].sort_values(by="Word_count")
spam_mid.head()
# Out:
#                              Seller Review Review_new  Char  Segm_count  \
# 22396         Romand_Official Store   Ưng         Ưng     4           1
# 93969   Perfect Diary Official Shop   Okee       Okee     4           1
# 94392   Perfect Diary Official Shop   Xịn!       Xịn!     4           1
# 149431                    Abpopa.vn   11đ         11đ     4           1
# 148654        Ineyoo Official Store   Đeph       Đeph     4           1
#
#         Word_count  Char/Wcount
# 22396            1          4.0
# 93969            1          4.0
# 94392            1          4.0
# 149431           1          4.0
# 148654           1          4.0

# %%
spam_lower.head()
# Out:
#                           Seller Review Review_new  Char  Segm_count  \
# 5586    PINKFLASH Official Store      😘          😘     1           1
# 3762    PINKFLASH Official Store      s          s     1           1
# 4505    PINKFLASH Official Store      B          B     1           1
# 136918  Herorange Official Store      H          H     1           1
# 135443  Herorange Official Store      E          E     1           1
#
#         Word_count  Char/Wcount
# 5586             1          1.0
# 3762             1          1.0
# 4505             1          1.0
# 136918           1          1.0
# 135443           1          1.0

# %%
spam_upper.head()
# Out:
#                           Seller  \
# 169334               JENNY SHOPP
# 149904                 Abpopa.vn
# 139910  Herorange Official Store
# 91312    Colorkey Official Store
# 137150  Herorange Official Store
#
#                                                    Review  \
# 169334  Chào hỏi khách,  giới thiệu chương trình ưu đã...
# 149904  Monkey mở cửa vào thế giới những chiếc lá mới ...
# 139910  I got an error when visiting heyhey.net/.  Err...
# 91312   [TB] TRỌN GÓI 10K - BAO DATA,  GỌI CẢ NGÀY! 1....
# 137150  Mẹo người dùng:  tốt Bao bì:  Tốt Hiệu ứng làm...
#
#                                                Review_new  Char  Segm_count  \
# 169334  Chào_hỏi khách, giới_thiệu chương_trình ưu_đãi...   361          50
# 149904  Monkey mở_cửa vào thế_giới những chiếc lá mới ...  4689         793
# 139910  I got an error when visiting heyhey.net/. Erro...   361          71
# 91312   [TB] TRỌN_GÓI 10K - BAO DATA, GỌI CẢ NGÀY! 1. ...   336          63
# 137150  Mẹo người dùng: tốt Bao bì: Tốt_Hiệu ứng làm đ...   396          75
#
#         Word_count  Char/Wcount
# 169334          72         5.01
# 149904         935         5.01
# 139910          72         5.01
# 91312           67         5.01
# 137150          79         5.01

# %% [markdown]
# # Temporal analysis of reviews

# %% [markdown]
# ## Extract month from date in M format and time from date in hh format

# %%
# GMT is shifted up 4 hours
df['Date'] = df['Date'] - pd.Timedelta(hours=4)

# %%
df['Day'] = pd.to_datetime(df['Date']).dt.to_period('M')

# %%
df['Time'] = pd.to_datetime(df['Date']).dt.strftime('%H')

# %%
df.head(3)
# Out:
#                       Seller     Customer          Product name  \
# 0  Sweet mint Official Store  hai_yen2208  Pink Coco Son kem lì
# 1  Sweet mint Official Store      k*****5  Pink Coco Son kem lì
# 2  Sweet mint Official Store      p*****7  Pink Coco Son kem lì
#
#                  Date  Rating  \
# 0 2023-04-09 13:06:07       5
# 1 2023-04-17 01:44:39       1
# 2 2023-04-20 05:32:24       5
#
#                                               Review Version Oversea Shopping  \
# 0  Sản phẩm okla nha mn, màu lên đúng hình trên ả...       5               no
# 1  Sản phẩm thì là vỏ ko\nKo có son bên trong\nKo...       4               no
# 2  Làm đẹp:môi\n\nGiá rẻ mà chất lượng màu cũng s...       4               no
#
#   Picture included      Day Time
# 0               no  2023-04   13
# 1               no  2023-04   01
# 2              yes  2023-04   05

# %%
df_spam_fil_raw = df_text.copy()

# %%
df_spam_fil_raw["Time"] = df["Time"]

# %%
df_spam_fil_raw["Day"] = df["Day"]

# %%
df_spam_fil_raw["Rating"] = df["Rating"]

# %%
df_spam_fil_raw = df_spam_fil_raw.loc[(df_text["Char/Wcount"] > 3.5) & (df_text["Char/Wcount"] < 5) & (df_text["Word_count"] >= 4)].copy()

# %%
def filter_spam(review):
    words = review.split()
    long_words = [long for long in words if len(long) > 7]
    return len(long_words) == 0

df_spam_fil_raw = df_spam_fil_raw[df_spam_fil_raw['Review'].apply(filter_spam)]

# %%
df_spam_fil_raw.head()
# Out:
#                       Seller  \
# 0  Sweet mint Official Store
# 1  Sweet mint Official Store
# 2  Sweet mint Official Store
# 3  Sweet mint Official Store
# 4  Sweet mint Official Store
#
#                                               Review  \
# 0  Sản phẩm okla nha mn,  màu lên đúng hình trên ...
# 1  Sản phẩm thì là vỏ ko Ko có son bên trong Ko h...
# 2  Làm đẹp: môi  Giá rẻ mà chất lượng màu cũng si...
# 3  Hiệu ứng làm đẹp: rất là đẹp 😍 Kinh nghiệm sử ...
# 4  Hiệu ứng làm đẹp: tốt Kinh nghiệm sử dụng: ko ...
#
#                                           Review_new  Char  Segm_count  \
# 0  Sản_phẩm okla nha mn, màu lên đúng hình trên ả...    74          13
# 1  Sản_phẩm thì là vỏ ko Ko có_son bên trong Ko h...    53          11
# 2  Làm đẹp: môi Giá rẻ mà chất_lượng màu cũng siê...    74          15
# 3  Hiệu_ứng làm đẹp: rất là đẹp 😍 Kinh_nghiệm sử ...    66          13
# 4  Hiệu_ứng làm đẹp: tốt Kinh_nghiệm sử dụng: ko ...    68          14
#
#    Word_count  Char/Wcount Time      Day  Rating
# 0          15         4.93   13  2023-04       5
# 1          14         3.79   01  2023-04       1
# 2          16         4.62   05  2023-04       5
# 3          16         4.12   01  2023-05       5
# 4          16         4.25   07  2023-05       5

# %% [markdown]
# ## Number of comments per month

# %%
seller = df["Seller"].unique()
date_count_old = df.groupby("Seller")["Day"].value_counts()
date_count_new = df_spam_fil_raw.groupby("Seller")["Day"].value_counts()


fig, axes = plt.subplots(ncols=5, nrows=8, figsize=(15, 18))
axes = axes.flatten()

for i, val in enumerate(seller):
    ax = axes[i]
    ax.set_title(f'{val}')
    ax.set_xlabel('Month')
    ax.set_ylabel('Monthly Count')

    if len(date_count_old[val]) <= 10:
        tick_interval = 2
    elif 10 < len(date_count_old[val]) <= 20:
        tick_interval = 3
    elif 20 <= len(date_count_old[val]) < 40:
        tick_interval = 4
    elif 40 < len(date_count_old[val]):
        tick_interval = 10

    if val in date_count_old.index.levels[0]:
        count_old = date_count_old[val].sort_index()
        count_new = date_count_new[val].sort_index()
        x = [str(index) for index in count_old.index]
        y = [str(index) for index in count_new.index]
        ax.plot(x, count_old.values, color="black", label="Before")
        ax.plot(y, count_new.values, color="hotpink", label="After")

        xticks_indices = range(0, len(count_old), tick_interval)
        ax.set_xticks(xticks_indices)
        ax.set_xticklabels([x[i] for i in xticks_indices], rotation=90)

for ax in axes[len(seller):]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Number of comments per hour after rough processing

# %%
seller = df_spam_fil_raw["Seller"].unique()
time_count_new = df_spam_fil_raw.groupby("Seller")["Time"].value_counts()
time_count_old = df.groupby("Seller")["Time"].value_counts()

fig, axes = plt.subplots(ncols=5, nrows=8, figsize=(15, 18))
axes = axes.flatten()

tick_interval = 3

for i, val in enumerate(seller):
    ax = axes[i]
    ax.set_title(f'{val}')
    ax.set_xlabel('Time')
    ax.set_ylabel('Count by time')

    if val in time_count_old.index.levels[0]:
        count_new = time_count_new[val].sort_index()
        count_old = time_count_old[val].sort_index()
        x = [str(index) for index in count_old.index]
        y = [str(index) for index in count_new.index]
        ax.plot(x, count_old.values, color="black")
        ax.plot(y, count_new.values, color="hotpink")

        xticks_indices = range(0, len(count_old), tick_interval)
        ax.set_xticks(xticks_indices)
        ax.set_xticklabels([x[i] for i in xticks_indices], rotation=90)


for ax in axes[len(seller):]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data for spam review analysis

# %%
df_spam_fil_raw.reset_index(inplace=True)

# %%
df_spam_fil_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176759 entries, 0 to 176758
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Seller       176759 non-null  object
#  1   Review       176759 non-null  object
#  2   Review_new   176759 non-null  object
#  3   Char         176759 non-null  int64
#  4   Segm_count   176759 non-null  int64
#  5   Word_count   176759 non-null  int64
#  6   Char/Wcount  176759 non-null  float64
#  7   Time         176759 non-null  object
#  8   Day          176759 non-null  period[M]
#  9   Rating       176759 non-null  int64
# dtypes: float64(1), int64(4), object(4), period[M](1)
# memory usage: 13.5+ MB

# %%
df_spam_fil_raw.head()
# Out:
#                       Seller  \
# 0  Sweet mint Official Store
# 1  Sweet mint Official Store
# 2  Sweet mint Official Store
# 3  Sweet mint Official Store
# 4  Sweet mint Official Store
#
#                                               Review  \
# 0  Sản phẩm okla nha mn,  màu lên đúng hình trên ...
# 1  Sản phẩm thì là vỏ ko Ko có son bên trong Ko h...
# 2  Làm đẹp: môi  Giá rẻ mà chất lượng màu cũng si...
# 3  Hiệu ứng làm đẹp: rất là đẹp 😍 Kinh nghiệm sử ...
# 4  Hiệu ứng làm đẹp: tốt Kinh nghiệm sử dụng: ko ...
#
#                                           Review_new  Char  Segm_count  \
# 0  Sản_phẩm okla nha mn, màu lên đúng hình trên ả...    74          13
# 1  Sản_phẩm thì là vỏ ko Ko có_son bên trong Ko h...    53          11
# 2  Làm đẹp: môi Giá rẻ mà chất_lượng màu cũng siê...    74          15
# 3  Hiệu_ứng làm đẹp: rất là đẹp 😍 Kinh_nghiệm sử ...    66          13
# 4  Hiệu_ứng làm đẹp: tốt Kinh_nghiệm sử dụng: ko ...    68          14
#
#    Word_count  Char/Wcount Time      Day  Rating
# 0          15         4.93   13  2023-04       5
# 1          14         3.79   01  2023-04       1
# 2          16         4.62   05  2023-04       5
# 3          16         4.12   01  2023-05       5
# 4          16         4.25   07  2023-05       5
